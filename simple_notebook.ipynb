# %%
import numpy as np
import finch_functions
from math import pi

# %%
finch_e = finch_functions.finchEvolver(N_finches=2)

# %%
N_gen = 3

theta_i = np.array([pi/2,pi/2,pi/2,pi/2,pi/2,pi/2,pi/2,pi/2])
theta_intra = [[pi/10,pi/10],[pi/10,pi/10]]
theta_inter = [pi/4, pi/4]

preferred_characteristics = np.array([1,1,1,1,0,0,0,0])
multiplier = 0*np.array([1,1,1,1,1,1,1,1])

shots = 50

# %%
finch_e.draw_q_circuit(theta_i, theta_intra, theta_inter)
# Out:
#      ┌─────────┐            ┌──────────┐                         ░          »
# q_0: ┤ Rx(π/2) ├─────■──────┤ Rx(π/10) ├─────────────────────────░─────■────»
#      ├─────────┤     │      └────┬─────┘            ┌──────────┐ ░     │    »
# q_1: ┤ Rx(π/2) ├─────┼───────────┼───────────■──────┤ Rx(π/10) ├─░─────┼────»
#      ├─────────┤┌────┴─────┐     │      ┌────┴─────┐└────┬─────┘ ░     │    »
# q_2: ┤ Rx(π/2) ├┤ Rx(π/10) ├─────■──────┤ Rx(π/10) ├─────■───────░─────┼────»
#      ├─────────┤└──────────┘            └──────────┘             ░     │    »
# q_3: ┤ Rx(π/2) ├─────────────────────────────────────────────────░─────┼────»
#      ├─────────┤            ┌──────────┐                         ░ ┌───┴───┐»
# q_4: ┤ Rx(π/2) ├─────■──────┤ Rx(π/10) ├─────────────────────────░─┤ Rx(π) ├»
#      ├─────────┤     │      └────┬─────┘            ┌──────────┐ ░ └───────┘»
# q_5: ┤ Rx(π/2) ├─────┼───────────┼───────────■──────┤ Rx(π/10) ├─░──────────»
#      ├─────────┤┌────┴─────┐     │      ┌────┴─────┐└────┬─────┘ ░          »
# q_6: ┤ Rx(π/2) ├┤ Rx(π/10) ├─────■──────┤ Rx(π/10) ├─────■───────░──────────»
#      ├─────────┤└──────────┘            └──────────┘             ░          »
# q_7: ┤ Rx(π/2) ├─────────────────────────────────────────────────░──────────»
#      └─────────┘                                                 ░          »
# c: 8/═══════════════════════════════════════════════════════════════════════»
#                                                                             »
# «     ┌─────────┐          ░                               ░             »
# «q_0: ┤ Rx(π/4) ├────■─────░───────────────────────────────░──────■──────»
# «     └────┬────┘    │     ░                               ░      │      »
# «q_1: ─────┼─────────┼─────░───────────────────────────────░──────┼──────»
# «          │         │     ░                               ░ ┌────┴─────┐»
# «q_2: ─────┼─────────┼─────░───────────────────────────────░─┤ Rx(π/10) ├»
# «          │         │     ░          ┌─────────┐          ░ └──────────┘»
# «q_3: ─────┼─────────┼─────░─────■────┤ Rx(π/4) ├────■─────░─────────────»
# «          │     ┌───┴───┐ ░     │    └────┬────┘    │     ░             »
# «q_4: ─────■─────┤ Rx(π) ├─░─────┼─────────┼─────────┼─────░──────■──────»
# «                └───────┘ ░     │         │         │     ░      │      »
# «q_5: ─────────────────────░─────┼─────────┼─────────┼─────░──────┼──────»
# «                          ░     │         │         │     ░ ┌────┴─────┐»
# «q_6: ─────────────────────░─────┼─────────┼─────────┼─────░─┤ Rx(π/10) ├»
# «                          ░ ┌───┴───┐     │     ┌───┴───┐ ░ └──────────┘»
# «q_7: ─────────────────────░─┤ Rx(π) ├─────■─────┤ Rx(π) ├─░─────────────»
# «                          ░ └───────┘           └───────┘ ░             »
# «c: 8/═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «     ┌──────────┐                         ░ ┌─┐
# «q_0: ┤ Rx(π/10) ├─────────────────────────░─┤M├─────────────────────
# «     └────┬─────┘            ┌──────────┐ ░ └╥┘┌─┐
# «q_1: ─────┼───────────■──────┤ Rx(π/10) ├─░──╫─┤M├──────────────────
# «          │      ┌────┴─────┐└────┬─────┘ ░  ║ └╥┘┌─┐
# «q_2: ─────■──────┤ Rx(π/10) ├─────■───────░──╫──╫─┤M├───────────────
# «                 └──────────┘             ░  ║  ║ └╥┘┌─┐
# «q_3: ─────────────────────────────────────░──╫──╫──╫─┤M├────────────
# «     ┌──────────┐                         ░  ║  ║  ║ └╥┘┌─┐
# «q_4: ┤ Rx(π/10) ├─────────────────────────░──╫──╫──╫──╫─┤M├─────────
# «     └────┬─────┘            ┌──────────┐ ░  ║  ║  ║  ║ └╥┘┌─┐
# «q_5: ─────┼───────────■──────┤ Rx(π/10) ├─░──╫──╫──╫──╫──╫─┤M├──────
# «          │      ┌────┴─────┐└────┬─────┘ ░  ║  ║  ║  ║  ║ └╥┘┌─┐
# «q_6: ─────■──────┤ Rx(π/10) ├─────■───────░──╫──╫──╫──╫──╫──╫─┤M├───
# «                 └──────────┘             ░  ║  ║  ║  ║  ║  ║ └╥┘┌─┐
# «q_7: ─────────────────────────────────────░──╫──╫──╫──╫──╫──╫──╫─┤M├
# «                                          ░  ║  ║  ║  ║  ║  ║  ║ └╥┘
# «c: 8/════════════════════════════════════════╩══╩══╩══╩══╩══╩══╩══╩═
# «                                             0  1  2  3  4  5  6  7

# %%
finch_e.multi_generation_evolution_plotting(N_gen, theta_i, theta_intra, theta_inter, preferred_characteristics, multiplier, shots)
